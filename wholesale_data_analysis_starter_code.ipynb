# %% [markdown]
# ## Part 1: Explore the Data
#
# Import the data and use Pandas to learn more about the dataset.

# %%
import pandas as pd

df = pd.read_csv('Resources/client_dataset.csv')
df.head()
# Out:
#        first      last                    job               phone  \
# 0     Donald   Harding           Immunologist  793-904-7725x39308
# 1    Tiffany     Myers        Music therapist    201.442.4543x942
# 2    Shannon    Watson           Immunologist   687.737.9424x8503
# 3     Nathan     Baker  Accounting technician    827-788-8123x012
# 4  Christina  Schwartz           Chiropractor        265-829-3643
#
#                                  email  client_id  order_id  order_date  \
# 0     harding.donald.7185@sullivan.com      58515   8953482  2023-04-28
# 1    myers.t.6537@ferguson-johnson.net      37609   8069089  2023-05-19
# 2                swatson8146@payne.net      57113   1902144  2023-01-29
# 3               bakernathan@benson.com      46554   9031802  2023-04-25
# 4  christinaschwartz9252@mcconnell.com      92089   1322274  2023-05-28
#
#    order_week  order_year         item_id     category         subcategory  \
# ...

# %%
# View the column names in the data
df.columns
# Out:
# Index(['first', 'last', 'job', 'phone', 'email', 'client_id', 'order_id',
#        'order_date', 'order_week', 'order_year', 'item_id', 'category',
#        'subcategory', 'unit_price', 'unit_cost', 'unit_weight', 'qty',
#        'line_number'],
#       dtype='object')

# %%
# Use the describe function to gather some basic statistics
df.describe()
# Out:
#           client_id      order_id    order_week    order_year    unit_price  \
# count  54639.000000  5.463900e+04  54639.000000  54639.000000  54639.000000
# mean   54837.869416  5.470190e+06     11.359139   2022.993064    136.267207
# std    25487.438231  2.599807e+06      7.023499      0.082997    183.873135
# min    10033.000000  1.000886e+06      1.000000   2022.000000      0.010000
# 25%    33593.000000  3.196372e+06      6.000000   2023.000000     20.800000
# 50%    53305.000000  5.496966e+06     11.000000   2023.000000     68.310000
# 75%    78498.000000  7.733869e+06     17.000000   2023.000000    173.160000
# max    99984.000000  9.998480e+06     52.000000   2023.000000   1396.230000
#
#           unit_cost   unit_weight           qty   line_number
# count  54639.000000  54639.000000  5.463900e+04  54639.000000
# mean      99.446073      5.004116  5.702646e+02      2.979667
# std      133.164267      5.326599  1.879552e+04      2.436320
# ...

# %%
# Use this space to do any additional research
# and familiarize yourself with the data.
orderinayear = df["order_year"].value_counts().sort_index()
#orderinayear
grouped_counts_df = df[["order_year","category","subcategory"]].value_counts().reset_index(name='order_count')
grouped_counts_df
# Out:
#     order_year     category         subcategory  order_count
# 0         2023  consumables   bathroom supplies         6375
# 1         2023  consumables      paper products         5831
# 2         2023  consumables    kitchen supplies         5706
# 3         2023    furniture              tables         4505
# 4         2023    furniture              stands         4173
# 5         2023     software          accounting         3736
# 6         2023     software  project management         3498
# 7         2023        decor              plants         3447
# 8         2023        decor            wall art         3076
# 9         2023  consumables                misc         2870
# 10        2023    furniture             seating         2646
# 11        2023  consumables                pens         2584
# 12        2023        decor                misc         1380
# 13        2023     software           logistics         1105
# ...

# %%
# What three item categories had the most entries?
grouped_categories_df = df[["category"]].value_counts().reset_index(name='order_count')
grouped_categories_df
df_consumables = df[df["category"]=="consumables"]
df_consumables
# Out:
#            first       last                                      job  \
# 1        Tiffany      Myers                          Music therapist
# 3         Nathan      Baker                    Accounting technician
# 4      Christina   Schwartz                             Chiropractor
# 6          Brian      Moore                                  Barista
# 7          Jesus     Wright                       Theme park manager
# ...          ...        ...                                      ...
# 54629      Linda  Henderson  Scientist, research (physical sciences)
# 54632     Austin     Fuller                       Investment analyst
# 54633     Tamara      Jones                        Fish farm manager
# 54635    Derrick      Moore                                 Musician
# 54636     Monica  Gutierrez                         Graphic designer
#
#                      phone                                email  client_id  \
# ...

# %%
# For the category with the most entries, which subcategory had the most entries?
grouped_subcategories_df = df_consumables[["subcategory"]].value_counts().reset_index(name='order_count')
grouped_subcategories_df
# Out:
#          subcategory  order_count
# 0  bathroom supplies         6424
# 1     paper products         5874
# 2   kitchen supplies         5746
# 3               misc         2891
# 4               pens         2603

# %%
# Which five clients had the most entries in the data?
df_mostclientids = df["client_id"].value_counts().reset_index(name='clientid counts')
df_mostclientids.head(5)
# Out:
#    client_id  clientid counts
# 0      33615              220
# 1      66037              211
# 2      46820              209
# 3      38378              207
# 4      24741              207

# %%
# Store the client ids of those top 5 clients in a list.
top5clientids = df_mostclientids["client_id"].head(5).tolist()

top5clientids
# Out:
# [33615, 66037, 46820, 38378, 24741]

# %%
# How many total units (the qty column) did the client with the most entries order order?
df_mostqtyofaclient = df[df["client_id"] == 33615]
totalunits = df_mostqtyofaclient["qty"].sum()
print(f"Total units for client 33615 = {totalunits}")
# Out:
# Total units for client 33615 = 64313

# %% [markdown]
# ## Part 2: Transform the Data
# Do we know that this client spent the more money than client 66037? If not, how would we find out? Transform the data using the steps below to prepare it for analysis.

# %%
# Create a column that calculates the subtotal for each line using the unit_price and the qty
df['subtotal']=df["qty"] * df["unit_price"]
df
# Out:
#            first       last                      job               phone  \
# 0         Donald    Harding             Immunologist  793-904-7725x39308
# 1        Tiffany      Myers          Music therapist    201.442.4543x942
# 2        Shannon     Watson             Immunologist   687.737.9424x8503
# 3         Nathan      Baker    Accounting technician    827-788-8123x012
# 4      Christina   Schwartz             Chiropractor        265-829-3643
# ...          ...        ...                      ...                 ...
# 54634     Lauren      Reese           Radio producer  977.877.5272x11382
# 54635    Derrick      Moore                 Musician        358.661.5483
# 54636     Monica  Gutierrez         Graphic designer    294.805.9100x339
# 54637      Wanda    Solomon             Toxicologist       (311)767-4924
# 54638     Dwayne       Bell  Chief Financial Officer   606-619-7667x9508
#
#                                      email  client_id  order_id  order_date  \
# ...

# %%
# Create a column for shipping price.
# Assume a shipping price of $7 per pound for orders over 50 pounds and $10 per pound for items 50 pounds or under.

df["shippingprice"] = df["unit_weight"] * df["qty"].apply(lambda w: w * 7 if w > 50 else w * 10 )
df
# Out:
#            first       last                      job               phone  \
# 0         Donald    Harding             Immunologist  793-904-7725x39308
# 1        Tiffany      Myers          Music therapist    201.442.4543x942
# 2        Shannon     Watson             Immunologist   687.737.9424x8503
# 3         Nathan      Baker    Accounting technician    827-788-8123x012
# 4      Christina   Schwartz             Chiropractor        265-829-3643
# ...          ...        ...                      ...                 ...
# 54634     Lauren      Reese           Radio producer  977.877.5272x11382
# 54635    Derrick      Moore                 Musician        358.661.5483
# 54636     Monica  Gutierrez         Graphic designer    294.805.9100x339
# 54637      Wanda    Solomon             Toxicologist       (311)767-4924
# 54638     Dwayne       Bell  Chief Financial Officer   606-619-7667x9508
#
#                                      email  client_id  order_id  order_date  \
# ...

# %%
# Create a column for the total price using the subtotal and the shipping price along with a sales tax of 9.25%
df["totalprice"]=( (df["subtotal"] + df["shippingprice"]) * ( 1 + 0.0925))
df
# Out:
#            first       last                      job               phone  \
# 0         Donald    Harding             Immunologist  793-904-7725x39308
# 1        Tiffany      Myers          Music therapist    201.442.4543x942
# 2        Shannon     Watson             Immunologist   687.737.9424x8503
# 3         Nathan      Baker    Accounting technician    827-788-8123x012
# 4      Christina   Schwartz             Chiropractor        265-829-3643
# ...          ...        ...                      ...                 ...
# 54634     Lauren      Reese           Radio producer  977.877.5272x11382
# 54635    Derrick      Moore                 Musician        358.661.5483
# 54636     Monica  Gutierrez         Graphic designer    294.805.9100x339
# 54637      Wanda    Solomon             Toxicologist       (311)767-4924
# 54638     Dwayne       Bell  Chief Financial Officer   606-619-7667x9508
#
#                                      email  client_id  order_id  order_date  \
# ...

# %%
# Create a column for the cost of each line using unit cost, qty, and
# shipping price (assume the shipping cost is exactly what is charged to the client).

df["totalcost"]=((df["unit_cost"] * df["qty"]) + df["shippingprice"]) 
df
# Out:
#            first       last                      job               phone  \
# 0         Donald    Harding             Immunologist  793-904-7725x39308
# 1        Tiffany      Myers          Music therapist    201.442.4543x942
# 2        Shannon     Watson             Immunologist   687.737.9424x8503
# 3         Nathan      Baker    Accounting technician    827-788-8123x012
# 4      Christina   Schwartz             Chiropractor        265-829-3643
# ...          ...        ...                      ...                 ...
# 54634     Lauren      Reese           Radio producer  977.877.5272x11382
# 54635    Derrick      Moore                 Musician        358.661.5483
# 54636     Monica  Gutierrez         Graphic designer    294.805.9100x339
# 54637      Wanda    Solomon             Toxicologist       (311)767-4924
# 54638     Dwayne       Bell  Chief Financial Officer   606-619-7667x9508
#
#                                      email  client_id  order_id  order_date  \
# ...

# %%
# Create a column for the profit of each line using line cost and line price
df["profit"] = df["totalprice"] - df["totalcost"]
df
# Out:
#            first       last                      job               phone  \
# 0         Donald    Harding             Immunologist  793-904-7725x39308
# 1        Tiffany      Myers          Music therapist    201.442.4543x942
# 2        Shannon     Watson             Immunologist   687.737.9424x8503
# 3         Nathan      Baker    Accounting technician    827-788-8123x012
# 4      Christina   Schwartz             Chiropractor        265-829-3643
# ...          ...        ...                      ...                 ...
# 54634     Lauren      Reese           Radio producer  977.877.5272x11382
# 54635    Derrick      Moore                 Musician        358.661.5483
# 54636     Monica  Gutierrez         Graphic designer    294.805.9100x339
# 54637      Wanda    Solomon             Toxicologist       (311)767-4924
# 54638     Dwayne       Bell  Chief Financial Officer   606-619-7667x9508
#
#                                      email  client_id  order_id  order_date  \
# ...

# %% [markdown]
# ## Part 3: Confirm your work
# You have email receipts showing that the total prices for 3 orders. Confirm that your calculations match the receipts. Remember, each order has multiple lines.
#
# Order ID 2742071 had a total price of \$152,811.89
#
# Order ID 2173913 had a total price of \$162,388.71
#
# Order ID 6128929 had a total price of \$923,441.25

# %%
# Check your work using the totals above
orderids = [2742071,2173913,6128929]

df_filtered = df[df["order_id"].isin(orderids)]
df_filtered = df_filtered.groupby("order_id")['totalprice'].sum().reset_index()
df_filtered
# Out:
#    order_id     totalprice
# 0   2173913  163237.067400
# 1   2742071  153250.295475
# 2   6128929  925642.409450

# %% [markdown]
# ## Part 4: Summarize and Analyze
# Use the new columns with confirmed values to find the following information.

# %%
# How much did each of the top 5 clients by quantity spend? Check your work from Part 1 for client ids.
df_topclient = df.groupby("client_id")["qty"].sum().reset_index()
df_topclient.sort_values("qty",ascending=False).head(5)
# Out:
#      client_id      qty
# 758      78965  4033302
# 850      86721  1010426
# 204      30143   846069
# 840      85931   644423
# 738      77354   506382

# %%
# Create a summary DataFrame showing the totals for the for the top 5 clients with the following information:
# total units purchased, total shipping price, total revenue, and total profit. 
df_topclientsummary = df.groupby("client_id").agg(TotalUnitsPurchased = ("qty","sum"),TotalShippingPrice = ("shippingprice","sum"),TotalRevenue=("totalprice","sum"),TotalProfit=("profit","sum"))
df_topclientsummary = df_topclientsummary.sort_values("TotalUnitsPurchased",ascending=False).head(5)
df_topclientsummary
# Out:
#            TotalUnitsPurchased  TotalShippingPrice  TotalRevenue   TotalProfit
# client_id
# 78965                  4033302          5367430.18  6.559528e+08  2.473553e+08
# 86721                  1010426         64351677.97  1.812837e+08  4.297617e+07
# 30143                   846069          8986402.93  3.333376e+07  1.125080e+07
# 85931                   644423         10133767.99  2.374293e+08  1.092952e+08
# 77354                   506382         23822698.47  7.195141e+07  1.243300e+07

# %%
# Format the data and rename the columns to names suitable for presentation.
from decimal import Decimal 

# Define the money columns. 
df_topclientsummary["TotalShippingPrice"] = df_topclientsummary["TotalShippingPrice"].apply(lambda x: Decimal(x)).map('${:,.2f}'.format)
#df_topclientsummary["TotalRevenue"] = df_topclientsummary["TotalRevenue"].apply(lambda x: Decimal(x)).map('${:,.2f}'.format)
#df_topclientsummary["TotalProfit"] = df_topclientsummary["TotalProfit"].apply(lambda x: Decimal(x)).map('${:,.2f}'.format)
#df_topclientsummary

def dollartomillions(amount):
    millions = (amount) / 100000
    return f"${millions:,.2f}M"
    

# Define a function that converts a dollar amount to millions.

# Apply the currency_format_millions function to only the money columns. 
df_topclientsummary["TotalRevenueInMillions"]=df_topclientsummary["TotalRevenue"].apply(lambda x: dollartomillions(x))
df_topclientsummary["TotalProfitInMillions"]=df_topclientsummary["TotalProfit"].apply(lambda x: dollartomillions(x))
df_topclientsummary["TotalRevenue"] = df_topclientsummary["TotalRevenue"].apply(lambda x: Decimal(x)).map('${:,.2f}'.format)
df_topclientsummary["TotalProfit"] = df_topclientsummary["TotalProfit"].apply(lambda x: Decimal(x)).map('${:,.2f}'.format)



# Rename the columns to reflect the change in the money format. 
df_topclientsummary.rename(columns = {'client_id': 'Client ID','TotalUnitsPurchased': 'Total Units Purchased','TotalShippingPrice':'Total Shipping Price','TotalRevenue':'Total Revenue','TotalProfit': 'Total Profit','TotalRevenueInMillions': 'Total Revenue (millions)','TotalProfitInMillions': 'Total Profit (millions)'},inplace=True)
df_topclientsummary
# Out:
#            Total Units Purchased Total Shipping Price    Total Revenue  \
# client_id
# 78965                    4033302        $5,367,430.18  $655,952,810.64
# 86721                    1010426       $64,351,677.97  $181,283,722.72
# 30143                     846069        $8,986,402.93   $33,333,763.56
# 85931                     644423       $10,133,767.99  $237,429,257.96
# 77354                     506382       $23,822,698.47   $71,951,405.56
#
#               Total Profit Total Revenue (millions) Total Profit (millions)
# client_id
# 78965      $247,355,309.75               $6,559.53M              $2,473.55M
# 86721       $42,976,170.89               $1,812.84M                $429.76M
# 30143       $11,250,801.93                 $333.34M                $112.51M
# 85931      $109,295,166.56               $2,374.29M              $1,092.95M
# 77354       $12,433,001.28                 $719.51M                $124.33M

# %%
# Sort the updated data by "Total Profit (millions)" form highest to lowest and assign the sort to a new DatFrame.
df_topclientsummary["Total Profit (millions)"] = df_topclientsummary["Total Profit (millions)"].replace({'\$':'',',':'','M':''},regex=True).astype(float)
#df_topclientsummary
new_df = df_topclientsummary.sort_values("Total Profit (millions)",ascending=False)
new_df["Total Profit (millions)"]= new_df["Total Profit (millions)"].map('${:,.2f}M'.format)
new_df
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\$'
# <>:2: SyntaxWarning: invalid escape sequence '\$'
# C:\Users\sowmy\AppData\Local\Temp\ipykernel_41708\1023246125.py:2: SyntaxWarning: invalid escape sequence '\$'
#   df_topclientsummary["Total Profit (millions)"] = df_topclientsummary["Total Profit (millions)"].replace({'\$':'',',':'','M':''},regex=True).astype(float)
#            Total Units Purchased Total Shipping Price    Total Revenue  \
# client_id
# 78965                    4033302        $5,367,430.18  $655,952,810.64
# 85931                     644423       $10,133,767.99  $237,429,257.96
# 86721                    1010426       $64,351,677.97  $181,283,722.72
# 77354                     506382       $23,822,698.47   $71,951,405.56
# 30143                     846069        $8,986,402.93   $33,333,763.56
#
#               Total Profit Total Revenue (millions) Total Profit (millions)
# client_id
# 78965      $247,355,309.75               $6,559.53M              $2,473.55M
# ...

# %%
'''Summary 
ClientID - 78965 made the highest profit of approx $2,470M with total revenue of $6500M
ClientID - 85931 made the second profit of approx $1080M with total revenue of $2270M. The total units purchased is far less than the client id with the highest profit
'''
# Out:
# 'Summary \nClientID - 78965 made the highest profit of approx $2,470M with total revenue of $6500M\nClientID - 85931 made the second profit of approx $1080M with total revenue of $2270M. The total units purchased is far less than the client id with the highest profit\n'
